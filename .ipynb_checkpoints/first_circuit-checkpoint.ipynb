# %%
from qiskit import *
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
qc = QuantumCircuit(3)

qc.h(0)
qc.h(1)
qc.x(0)
qc.x(1)
qc.cx(0,1)

qc.draw("mpl")

# %%
qc.cx(1,2)

qc.draw("mpl")
